# %%
from pyiceberg.catalog import load_catalog
from pyiceberg.schema import Schema
from pyiceberg.types import StringType, LongType, NestedField
from pyiceberg.table import TableIdentifier
from pyiceberg.catalog.sql import SqlCatalog
# Load the catalog from the config file
import os

# %%
folder_path = 'sqllite_s3'

# Create folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# %%
# Set AWS credentials via environment variables (optional if ~/.aws/credentials is set)
os.environ["AWS_ACCESS_KEY_ID"] = "Qmhm2qgYBFEPTBE"
os.environ["AWS_SECRET_ACCESS_KEY"] = "@eaenaYgZtxfb&53"
os.environ["AWS_ENDPOINT_URL"] = "https://p2-minio-dev.gates-staging.work/"
# Optional if using session token
# os.environ["AWS_SESSION_TOKEN"] = "your_session_token"
os.environ["AWS_REGION"] = "us-east-1"

# %%
catalog = SqlCatalog(
    "default",
    **{
        "uri": f"sqlite:///{folder_path}/icyhot.db",
        "warehouse": f"s3://demobucket/warehouse",
        "s3.endpoint": "https://p2-minio-dev.gates-staging.work/"
    },
)

# %%
print(catalog.properties)
# Out:
# {'uri': 'sqlite:///sqllite_s3/icyhot.db', 'warehouse': 's3://demobucket/warehouse', 's3.endpoint': 'https://p2-minio-dev.gates-staging.work/'}

# %%
catalog.create_namespace_if_not_exists('Sales')

# %%
from pyiceberg.schema import Schema
from pyiceberg.types import NestedField, IntegerType, StringType, FloatType, DoubleType, BooleanType
product_schema = Schema(
    NestedField(field_id=1, name='ProductId', field_type=IntegerType(), required=True),
    NestedField(field_id=2, name='Name', field_type=StringType(), required=True),
    NestedField(field_id=3, name='Category', field_type=StringType(), required=True),
    NestedField(field_id=4, name='Price', field_type=DoubleType(), required=True),
    NestedField(field_id=5, name='Stock', field_type=IntegerType(), required=True),
    NestedField(field_id=6, name='IsActive', field_type=BooleanType(), required=True)
)

# %%
product_table = catalog.create_table_if_not_exists(
    identifier="Sales.Product",
    schema=product_schema
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 product_table = catalog.create_table_if_not_exists(
#       2     identifier="Sales.Product",
#       3     schema=product_schema
#       4 )
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/catalog/__init__.py:437, in Catalog.create_table_if_not_exists(self, identifier, schema, location, partition_spec, sort_order, properties)
#     422 """Create a table if it does not exist.
#     423
#     424 Args:
#    (...)    434     table instance.
#     435 """
#     436 try:
# --> 437     return self.create_table(identifier, schema, location, partition_spec, sort_order, properties)
#     438 except TableAlreadyExistsError:
#     439     return self.load_table(identifier)
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/catalog/sql.py:221, in SqlCatalog.create_table(self, identifier, schema, location, partition_spec, sort_order, properties)
#     217 metadata = new_table_metadata(
#     218     location=location, schema=schema, partition_spec=partition_spec, sort_order=sort_order, properties=properties
#     219 )
#     220 io = load_file_io(properties=self.properties, location=metadata_location)
# --> 221 self._write_metadata(metadata, io, metadata_location)
#     223 with Session(self.engine) as session:
#     224     try:
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/catalog/__init__.py:1005, in MetastoreCatalog._write_metadata(metadata, io, metadata_path)
#    1003 @staticmethod
#    1004 def _write_metadata(metadata: TableMetadata, io: FileIO, metadata_path: str) -> None:
# -> 1005     ToOutputFile.table_metadata(metadata, io.new_output(metadata_path))
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/serializers.py:130, in ToOutputFile.table_metadata(metadata, output_file, overwrite)
#     122 @staticmethod
#     123 def table_metadata(metadata: TableMetadata, output_file: OutputFile, overwrite: bool = False) -> None:
#     124     """Write a TableMetadata instance to an output file.
#     125
#     126     Args:
#     127         output_file (OutputFile): A custom implementation of the iceberg.io.file.OutputFile abstract base class.
#     128         overwrite (bool): Where to overwrite the file if it already exists. Defaults to `False`.
#     129     """
# --> 130     with output_file.create(overwrite=overwrite) as output_stream:
#     131         # We need to serialize None values, in order to dump `None` current-snapshot-id as `-1`
#     132         exclude_none = False if Config().get_bool("legacy-current-snapshot-id") else True
#     134         json_bytes = metadata.model_dump_json(exclude_none=exclude_none).encode(UTF8)
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/io/pyarrow.py:366, in PyArrowFile.create(self, overwrite)
#     347 """Create a writable pyarrow.lib.NativeFile for this PyArrowFile's location.
#     348
#     349 Args:
#    (...)    363     truncate the contents of the existing file when opening the output stream.
#     364 """
#     365 try:
# --> 366     if not overwrite and self.exists() is True:
#     367         raise FileExistsError(f"Cannot create file, already exists: {self.location}")
#     368     output_file = self._filesystem.open_output_stream(self._path, buffer_size=self._buffer_size)
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/io/pyarrow.py:312, in PyArrowFile.exists(self)
#     310 """Check whether the location exists."""
#     311 try:
# --> 312     self._file_info()  # raises FileNotFoundError if it does not exist
#     313     return True
#     314 except FileNotFoundError:
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyiceberg/io/pyarrow.py:294, in PyArrowFile._file_info(self)
#     287 """Retrieve a pyarrow.fs.FileInfo object for the location.
#     288
#     289 Raises:
#     290     PermissionError: If the file at self.location cannot be accessed due to a permission error such as
#     291         an AWS error code 15.
#     292 """
#     293 try:
# --> 294     file_info = self._filesystem.get_file_info(self._path)
#     295 except OSError as e:
#     296     if e.errno == 13 or "AWS Error [code 15]" in str(e):
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyarrow/_fs.pyx:616, in pyarrow._fs.FileSystem.get_file_info()
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/tljh/user/envs/pyiceberg-polars-duckdb/lib/python3.14/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# OSError: When getting information for key 'warehouse/Sales/Product/metadata/00000-ef35ca9a-c97d-4b66-9ea1-dca8e176e50e.metadata.json' in bucket 'demobucket': AWS Error NETWORK_CONNECTION during HeadObject operation: curlCode: 60, SSL peer certificate or SSH remote key was not OK; Details: SSL certificate OpenSSL verify result: unable to get local issuer certificate (20)
